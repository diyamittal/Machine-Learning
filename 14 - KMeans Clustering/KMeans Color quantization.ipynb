# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg   # .jpg .png ----> numpy array
import seaborn as sns

# %%
image_as_array = mpimg.imread('DATA/palm_trees.jpg')

# %%
image_as_array
# Out:
# array([[[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 23,  63,  99],
#         [ 51,  91, 127],
#         [ 50,  90, 126]],
#
#        [[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 31,  71, 107],
#         [ 48,  88, 124],
#         [ 47,  90, 125]],
#
#        [[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 39,  79, 115],
#         [ 42,  85, 120],
#         [ 44,  88, 123]],
#
#        ...,
#
#        [[  4,   4,   6],
#         [  4,   4,   6],
#         [  4,   4,   6],
#         ...,
#         [  9,   9,  11],
#         [  9,   9,  11],
#         [  9,   9,  11]],
#
#        [[  3,   3,   5],
#         [  3,   3,   5],
#         [  3,   3,   5],
#         ...,
#         [  8,   8,  10],
#         [  8,   8,  10],
#         [  8,   8,  10]],
#
#        [[  4,   4,   6],
#         [  4,   4,   6],
#         [  4,   4,   6],
#         ...,
#         [  9,   9,  11],
#         [ 10,  10,  12],
#         [ 10,  10,  12]]], dtype=uint8)

# %%
image_as_array.shape # (H, W, C)
# Out:
# (1401, 934, 3)

# %%
plt.imshow(image_as_array)

# %%
# (H,W,C) ---> 2D (H*W,C)

# %%
(h, w, c) = image_as_array.shape

# %%
h
# Out:
# 1401

# %%
w
# Out:
# 934

# %%
c
# Out:
# 3

# %%
image_as_array2d = image_as_array.reshape(h*w,c)

# %%
image_as_array2d
# Out:
# array([[ 25,  89, 127],
#        [ 25,  89, 127],
#        [ 25,  89, 127],
#        ...,
#        [  9,   9,  11],
#        [ 10,  10,  12],
#        [ 10,  10,  12]], dtype=uint8)

# %%
len(image_as_array.shape)
# Out:
# 3

# %%
len(image_as_array2d.shape)
# Out:
# 2

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=6)

# %%
labels = model.fit_predict(image_as_array2d)
# Out:
# C:\Users\HP\anaconda3\envs\requirements\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
labels
# Out:
# array([4, 4, 4, ..., 0, 0, 0])

# %%
rgb_codes = model.cluster_centers_.round(0).astype(int)

# %%
rgb_codes
# Out:
# array([[  3,   3,   4],
#        [138, 144, 144],
#        [ 68,  62,  62],
#        [193, 155, 108],
#        [ 71, 110, 138],
#        [219, 135,  46]])

# %%
rgb_codes[labels]
# Out:
# array([4, 4, 4, ..., 0, 0, 0])

# %%
quantized_image = np.reshape(rgb_codes[labels], (h, w, c))

# %%
quantized_image
# Out:
# array([[[ 71, 110, 138],
#         [ 71, 110, 138],
#         [ 71, 110, 138],
#         ...,
#         [ 68,  62,  62],
#         [ 71, 110, 138],
#         [ 71, 110, 138]],
#
#        [[ 71, 110, 138],
#         [ 71, 110, 138],
#         [ 71, 110, 138],
#         ...,
#         [ 68,  62,  62],
#         [ 71, 110, 138],
#         [ 71, 110, 138]],
#
#        [[ 71, 110, 138],
#         [ 71, 110, 138],
#         [ 71, 110, 138],
#         ...,
#         [ 71, 110, 138],
#         [ 71, 110, 138],
#         [ 71, 110, 138]],
#
#        ...,
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]],
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]],
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]]])

# %%
plt.imshow(quantized_image)
